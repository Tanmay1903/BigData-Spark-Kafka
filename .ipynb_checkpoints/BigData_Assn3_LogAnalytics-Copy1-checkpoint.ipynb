# %%
# from pyspark.context import SparkContext
# from pyspark.sql.context import SQLContext
from pyspark.sql.session import SparkSession
from pyspark.conf import SparkConf

# load up other dependencies
import re
import pandas as pd
from pyspark.sql import functions as F
from pyspark.sql.functions import udf
from pyspark.sql.functions import regexp_extract

# %%
# sc = SparkContext()
# sqlContext = SQLContext(sc)
# Set Spark Configuration
conf = SparkConf() \
    .setMaster("local[*]") \
    .setAppName("LogAnalytics") \
    .setExecutorEnv("spark.executor.memory", "4g") \
    .setExecutorEnv("spark.driver.memory", "4g")


# Create a SparkSession
spark = SparkSession.builder \
    .config(conf = conf) \
    .getOrCreate()
# Out:
# 23/05/28 16:01:06 WARN Utils: Your hostname, Tanmays-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 10.0.0.123 instead (on interface en0)
# 23/05/28 16:01:06 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/05/28 16:01:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/05/28 16:01:08 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
df = spark.read.text("/Users/tanmaysingla/Downloads/17GBBigServerLog.log")

# %%
df.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)

# %%
df.count()
# Out:
# 119999999

# %%
df.filter(df['value'].isNull()).count()
# Out:
# 0

# %%
host_pattern = r'(^\S+\.[\S+\.]+\S+)\s'
ts_pattern = r'\[(\d{2}/\w{3}/\d{4}:\d{2}:\d{2}:\d{2} \+\d{4})\]'
method_uri_protocol_pattern = r'\"(\S+)\s(\S+)\s*(\S*)\"'
status_pattern = r'\s(\d{3})\s'
content_size_pattern = r'\s(\d+)$'

# %%
logs_df = df.select(regexp_extract('value', host_pattern, 1).alias('host'),
                         regexp_extract('value', ts_pattern, 1).alias('timestamp'),
                         regexp_extract('value', method_uri_protocol_pattern, 1).alias('method'),
                         regexp_extract('value', method_uri_protocol_pattern, 2).alias('endpoint'),
                         regexp_extract('value', method_uri_protocol_pattern, 3).alias('protocol'),
                         regexp_extract('value', status_pattern, 1).cast('integer').alias('status'),
                         regexp_extract('value', content_size_pattern, 1).cast('integer').alias('content_size'))
logs_df.show(10, truncate=True)
print((logs_df.count(), len(logs_df.columns)))
logs_df.cache()
# Out:
# +---------------+--------------------+------+--------------------+--------+------+------------+
# |           host|           timestamp|method|            endpoint|protocol|status|content_size|
# +---------------+--------------------+------+--------------------+--------+------+------------+
# |197.217.102.239|26/Dec/2118:12:00...|  POST|/Archives/edgar/d...|HTTP/1.0|   200|       17286|
# | 67.198.123.159|26/Dec/2118:12:00...|DELETE|/Archives/edgar/d...|HTTP/1.0|   500|       25023|
# | 93.136.152.153|26/Dec/2118:12:00...|DELETE|/Archives/edgar/d...|HTTP/1.0|   304|       51136|
# |187.198.113.102|26/Dec/2118:12:00...|  POST|/Archives/edgar/d...|HTTP/1.0|   200|        1266|
# | 34.180.234.250|26/Dec/2118:12:00...|  POST|/Archives/edgar/d...|HTTP/1.0|   304|       54427|
# |    63.1.139.91|26/Dec/2118:12:00...|   GET|/Archives/edgar/d...|HTTP/1.0|   502|       45037|
# | 181.39.225.239|26/Dec/2118:12:00...|   GET|/Archives/edgar/d...|HTTP/1.0|   303|       52160|
# |   78.154.11.19|26/Dec/2118:12:00...|DELETE|/Archives/edgar/d...|HTTP/1.0|   502|       18368|
# |  77.210.45.207|26/Dec/2118:12:00...|   PUT|/Archives/edgar/d...|HTTP/1.0|   500|       48227|
# |108.167.157.215|26/Dec/2118:12:00...|   PUT|/Archives/edgar/d...|HTTP/1.0|   200|       20973|
# +---------------+--------------------+------+--------------------+--------+------+------------+
# only showing top 10 rows
# [Stage 4:===================================================>   (121 + 7) / 128]
# (119999999, 7)
# DataFrame[host: string, timestamp: string, method: string, endpoint: string, protocol: string, status: int, content_size: int]

# %%
bad_rows_df = logs_df.filter(logs_df['host'].isNull()| 
                             logs_df['timestamp'].isNull() | 
                             logs_df['method'].isNull() |
                             logs_df['endpoint'].isNull() |
                             logs_df['status'].isNull() |
                             logs_df['content_size'].isNull()|
                             logs_df['protocol'].isNull())
bad_rows_df.count()
# Out:
# 23/05/28 16:35:06 WARN MemoryStore: Not enough space to cache rdd_22_8 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:35:06 WARN MemoryStore: Not enough space to cache rdd_22_12 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:35:06 WARN MemoryStore: Not enough space to cache rdd_22_13 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_18 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_19 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_22 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_16 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_23 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_21 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_20 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_17 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_27 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_31 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_30 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_29 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_25 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_26 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_28 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:07 WARN MemoryStore: Not enough space to cache rdd_22_24 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_38 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_33 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_35 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_37 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_34 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_32 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_39 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_36 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_40 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_46 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_44 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_41 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_43 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_42 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_47 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:08 WARN MemoryStore: Not enough space to cache rdd_22_45 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_54 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_55 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_51 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_48 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_52 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_49 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_53 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_50 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_63 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_56 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_60 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_57 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_58 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_62 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_61 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:09 WARN MemoryStore: Not enough space to cache rdd_22_59 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:10 WARN MemoryStore: Not enough space to cache rdd_22_70 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:10 WARN MemoryStore: Not enough space to cache rdd_22_64 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:10 WARN MemoryStore: Not enough space to cache rdd_22_71 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:10 WARN MemoryStore: Not enough space to cache rdd_22_66 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:10 WARN MemoryStore: Not enough space to cache rdd_22_65 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:10 WARN MemoryStore: Not enough space to cache rdd_22_67 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:10 WARN MemoryStore: Not enough space to cache rdd_22_68 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:10 WARN MemoryStore: Not enough space to cache rdd_22_69 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_79 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_78 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_76 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_75 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_77 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_72 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_74 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_73 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_85 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_81 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_87 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_84 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_80 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_83 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_82 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:11 WARN MemoryStore: Not enough space to cache rdd_22_86 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_89 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_94 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_91 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_90 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_92 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_88 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_95 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_93 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_99 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_103 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_101 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_96 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_97 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_98 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_100 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:12 WARN MemoryStore: Not enough space to cache rdd_22_102 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:13 WARN MemoryStore: Not enough space to cache rdd_22_107 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:13 WARN MemoryStore: Not enough space to cache rdd_22_109 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:13 WARN MemoryStore: Not enough space to cache rdd_22_104 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:13 WARN MemoryStore: Not enough space to cache rdd_22_110 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:13 WARN MemoryStore: Not enough space to cache rdd_22_108 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:13 WARN MemoryStore: Not enough space to cache rdd_22_106 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:13 WARN MemoryStore: Not enough space to cache rdd_22_105 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:13 WARN MemoryStore: Not enough space to cache rdd_22_111 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_118 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_114 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_119 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_112 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_113 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_117 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_116 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_115 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_123 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_127 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_125 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_122 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_126 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_121 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_124 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:35:14 WARN MemoryStore: Not enough space to cache rdd_22_120 in memory! (computed 9.0 MiB so far)
# 0

# %%
month_map = {
  'Jan': 1, 'Feb': 2, 'Mar':3, 'Apr':4, 'May':5, 'Jun':6, 'Jul':7,
  'Aug':8,  'Sep': 9, 'Oct':10, 'Nov': 11, 'Dec': 12
}

def parse_clf_time(text):
    """ Convert Common Log time format into a Python datetime object
    Args:
        text (str): date and time in Apache time format [dd/mmm/yyyy:hh:mm:ss (+/-)zzzz]
    Returns:
        a string suitable for passing to CAST('timestamp')
    """
    # NOTE: We're ignoring the time zones here, might need to be handled depending on the problem you are solving
    return "{0:04d}-{1:02d}-{2:02d} {3:02d}:{4:02d}:{5:02d}".format(
      int(text[7:11]),
      month_map[text[3:6]],
      int(text[0:2]),
      int(text[12:14]),
      int(text[15:17]),
      int(text[18:20])
    )

# %%
udf_parse_time = udf(parse_clf_time)

logs_df_with_time = (logs_df.select('*', udf_parse_time(logs_df['timestamp']).cast('timestamp').alias('time')).drop('timestamp'))
logs_df_with_time.show(10, truncate=True)
# Out:
# [Stage 10:>                                                         (0 + 1) / 1]
# +---------------+------+--------------------+--------+------+------------+-------------------+
# |           host|method|            endpoint|protocol|status|content_size|               time|
# +---------------+------+--------------------+--------+------+------------+-------------------+
# |197.217.102.239|  POST|/Archives/edgar/d...|HTTP/1.0|   200|       17286|2118-12-26 12:00:00|
# | 67.198.123.159|DELETE|/Archives/edgar/d...|HTTP/1.0|   500|       25023|2118-12-26 12:00:00|
# | 93.136.152.153|DELETE|/Archives/edgar/d...|HTTP/1.0|   304|       51136|2118-12-26 12:00:00|
# |187.198.113.102|  POST|/Archives/edgar/d...|HTTP/1.0|   200|        1266|2118-12-26 12:00:00|
# | 34.180.234.250|  POST|/Archives/edgar/d...|HTTP/1.0|   304|       54427|2118-12-26 12:00:00|
# |    63.1.139.91|   GET|/Archives/edgar/d...|HTTP/1.0|   502|       45037|2118-12-26 12:00:00|
# | 181.39.225.239|   GET|/Archives/edgar/d...|HTTP/1.0|   303|       52160|2118-12-26 12:00:00|
# |   78.154.11.19|DELETE|/Archives/edgar/d...|HTTP/1.0|   502|       18368|2118-12-26 12:00:00|
# |  77.210.45.207|   PUT|/Archives/edgar/d...|HTTP/1.0|   500|       48227|2118-12-26 12:00:00|
# |108.167.157.215|   PUT|/Archives/edgar/d...|HTTP/1.0|   200|       20973|2118-12-26 12:00:00|
# +---------------+------+--------------------+--------+------+------------+-------------------+
# only showing top 10 rows

# %%
logs_df_with_time.cache()
# Out:
# DataFrame[host: string, method: string, endpoint: string, protocol: string, status: int, content_size: int, time: timestamp]

# %%
content_size_summary_df = logs_df_with_time.describe(['content_size'])
content_size_summary_df.toPandas()
# Out:
# 23/05/28 16:11:21 WARN MemoryStore: Not enough space to cache rdd_46_2 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:11:21 WARN BlockManager: Persisting block rdd_46_2 to disk instead.
# 23/05/28 16:11:23 WARN MemoryStore: Not enough space to cache rdd_46_4 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:11:23 WARN MemoryStore: Not enough space to cache rdd_46_6 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:11:23 WARN BlockManager: Persisting block rdd_46_6 to disk instead.
# 23/05/28 16:11:23 WARN BlockManager: Persisting block rdd_46_4 to disk instead.
# 23/05/28 16:11:28 WARN MemoryStore: Not enough space to cache rdd_46_1 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:11:28 WARN MemoryStore: Not enough space to cache rdd_46_0 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:11:28 WARN BlockManager: Persisting block rdd_46_0 to disk instead.
# 23/05/28 16:11:28 WARN BlockManager: Persisting block rdd_46_1 to disk instead.
# 23/05/28 16:11:44 WARN MemoryStore: Not enough space to cache rdd_46_11 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:11:44 WARN MemoryStore: Not enough space to cache rdd_46_10 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:11:44 WARN BlockManager: Persisting block rdd_46_10 to disk instead.
# 23/05/28 16:11:44 WARN BlockManager: Persisting block rdd_46_11 to disk instead.
# 23/05/28 16:11:44 WARN MemoryStore: Not enough space to cache rdd_46_13 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:11:44 WARN MemoryStore: Not enough space to cache rdd_46_9 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:11:44 WARN BlockManager: Persisting block rdd_46_9 to disk instead.
# 23/05/28 16:11:44 WARN BlockManager: Persisting block rdd_46_13 to disk instead.
# 23/05/28 16:11:55 WARN MemoryStore: Not enough space to cache rdd_46_21 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:11:55 WARN MemoryStore: Not enough space to cache rdd_46_22 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:11:55 WARN BlockManager: Persisting block rdd_46_21 to disk instead.
# 23/05/28 16:11:55 WARN BlockManager: Persisting block rdd_46_22 to disk instead.
# 23/05/28 16:11:59 WARN MemoryStore: Not enough space to cache rdd_46_19 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:11:59 WARN BlockManager: Persisting block rdd_46_19 to disk instead.
# 23/05/28 16:11:59 WARN MemoryStore: Not enough space to cache rdd_46_17 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:11:59 WARN BlockManager: Persisting block rdd_46_17 to disk instead.
# 23/05/28 16:11:59 WARN MemoryStore: Not enough space to cache rdd_46_18 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:11:59 WARN BlockManager: Persisting block rdd_46_18 to disk instead.
# 23/05/28 16:11:59 WARN MemoryStore: Not enough space to cache rdd_46_23 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:11:59 WARN BlockManager: Persisting block rdd_46_23 to disk instead.
# 23/05/28 16:12:15 WARN MemoryStore: Not enough space to cache rdd_46_28 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:16 WARN BlockManager: Persisting block rdd_46_28 to disk instead.
# 23/05/28 16:12:16 WARN MemoryStore: Not enough space to cache rdd_46_30 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:16 WARN BlockManager: Persisting block rdd_46_30 to disk instead.
# 23/05/28 16:12:16 WARN MemoryStore: Not enough space to cache rdd_46_24 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:16 WARN BlockManager: Persisting block rdd_46_24 to disk instead.
# 23/05/28 16:12:16 WARN MemoryStore: Not enough space to cache rdd_46_27 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:16 WARN BlockManager: Persisting block rdd_46_27 to disk instead.
# 23/05/28 16:12:16 WARN MemoryStore: Not enough space to cache rdd_46_25 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:16 WARN BlockManager: Persisting block rdd_46_25 to disk instead.
# 23/05/28 16:12:27 WARN MemoryStore: Not enough space to cache rdd_46_39 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:12:27 WARN BlockManager: Persisting block rdd_46_39 to disk instead.
# 23/05/28 16:12:27 WARN MemoryStore: Not enough space to cache rdd_46_38 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:12:27 WARN BlockManager: Persisting block rdd_46_38 to disk instead.
# 23/05/28 16:12:31 WARN MemoryStore: Not enough space to cache rdd_46_36 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:31 WARN BlockManager: Persisting block rdd_46_36 to disk instead.
# 23/05/28 16:12:32 WARN MemoryStore: Not enough space to cache rdd_46_35 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:32 WARN BlockManager: Persisting block rdd_46_35 to disk instead.
# 23/05/28 16:12:38 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_46_47 in memory.
# 23/05/28 16:12:38 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_46_46 in memory.
# 23/05/28 16:12:39 WARN MemoryStore: Not enough space to cache rdd_46_47 in memory! (computed 384.0 B so far)
# 23/05/28 16:12:39 WARN MemoryStore: Not enough space to cache rdd_46_46 in memory! (computed 384.0 B so far)
# 23/05/28 16:12:39 WARN BlockManager: Persisting block rdd_46_46 to disk instead.
# 23/05/28 16:12:39 WARN BlockManager: Persisting block rdd_46_47 to disk instead.
# 23/05/28 16:12:47 WARN MemoryStore: Not enough space to cache rdd_46_40 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:47 WARN BlockManager: Persisting block rdd_46_40 to disk instead.
# 23/05/28 16:12:47 WARN MemoryStore: Not enough space to cache rdd_46_44 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:47 WARN MemoryStore: Not enough space to cache rdd_46_42 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:47 WARN BlockManager: Persisting block rdd_46_44 to disk instead.
# 23/05/28 16:12:47 WARN BlockManager: Persisting block rdd_46_42 to disk instead.
# 23/05/28 16:12:47 WARN MemoryStore: Not enough space to cache rdd_46_45 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:47 WARN BlockManager: Persisting block rdd_46_45 to disk instead.
# 23/05/28 16:12:47 WARN MemoryStore: Not enough space to cache rdd_46_41 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:12:47 WARN BlockManager: Persisting block rdd_46_41 to disk instead.
# 23/05/28 16:12:58 WARN MemoryStore: Not enough space to cache rdd_46_55 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:12:58 WARN BlockManager: Persisting block rdd_46_55 to disk instead.
# 23/05/28 16:12:58 WARN MemoryStore: Not enough space to cache rdd_46_52 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:12:58 WARN BlockManager: Persisting block rdd_46_52 to disk instead.
# 23/05/28 16:12:59 WARN MemoryStore: Not enough space to cache rdd_46_48 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:12:59 WARN BlockManager: Persisting block rdd_46_48 to disk instead.
# 23/05/28 16:12:59 WARN MemoryStore: Not enough space to cache rdd_46_50 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:12:59 WARN BlockManager: Persisting block rdd_46_50 to disk instead.
# 23/05/28 16:13:03 WARN MemoryStore: Not enough space to cache rdd_46_49 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:13:03 WARN BlockManager: Persisting block rdd_46_49 to disk instead.
# 23/05/28 16:13:03 WARN MemoryStore: Not enough space to cache rdd_46_53 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:13:04 WARN BlockManager: Persisting block rdd_46_53 to disk instead.
# 23/05/28 16:13:10 WARN MemoryStore: Not enough space to cache rdd_46_55 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:13:12 WARN MemoryStore: Not enough space to cache rdd_22_63 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:13:12 WARN MemoryStore: Not enough space to cache rdd_46_57 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:13:12 WARN BlockManager: Persisting block rdd_46_57 to disk instead.
# 23/05/28 16:13:12 WARN MemoryStore: Not enough space to cache rdd_46_58 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:13:12 WARN BlockManager: Persisting block rdd_46_58 to disk instead.
# 23/05/28 16:13:20 WARN MemoryStore: Not enough space to cache rdd_46_63 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:13:20 WARN BlockManager: Persisting block rdd_46_63 to disk instead.
# 23/05/28 16:13:28 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_46_71 in memory.
# 23/05/28 16:13:28 WARN MemoryStore: Not enough space to cache rdd_46_71 in memory! (computed 384.0 B so far)
# 23/05/28 16:13:28 WARN BlockManager: Persisting block rdd_46_71 to disk instead.
# 23/05/28 16:13:30 WARN MemoryStore: Not enough space to cache rdd_46_67 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:13:30 WARN BlockManager: Persisting block rdd_46_67 to disk instead.
# 23/05/28 16:13:30 WARN MemoryStore: Not enough space to cache rdd_46_65 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:13:30 WARN BlockManager: Persisting block rdd_46_65 to disk instead.
# 23/05/28 16:13:35 WARN MemoryStore: Not enough space to cache rdd_46_68 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:13:35 WARN BlockManager: Persisting block rdd_46_68 to disk instead.
# 23/05/28 16:13:36 WARN MemoryStore: Not enough space to cache rdd_46_69 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:13:36 WARN BlockManager: Persisting block rdd_46_69 to disk instead.
# 23/05/28 16:13:43 WARN MemoryStore: Not enough space to cache rdd_46_71 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:13:46 WARN MemoryStore: Not enough space to cache rdd_46_74 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:13:46 WARN BlockManager: Persisting block rdd_46_74 to disk instead.
# 23/05/28 16:13:51 WARN MemoryStore: Not enough space to cache rdd_46_73 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:13:51 WARN BlockManager: Persisting block rdd_46_73 to disk instead.
# 23/05/28 16:13:51 WARN MemoryStore: Not enough space to cache rdd_46_75 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:13:51 WARN BlockManager: Persisting block rdd_46_75 to disk instead.
# 23/05/28 16:13:51 WARN MemoryStore: Not enough space to cache rdd_46_72 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:13:51 WARN BlockManager: Persisting block rdd_46_72 to disk instead.
# 23/05/28 16:13:53 WARN MemoryStore: Not enough space to cache rdd_46_79 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:13:53 WARN BlockManager: Persisting block rdd_46_79 to disk instead.
# 23/05/28 16:14:07 WARN MemoryStore: Not enough space to cache rdd_46_82 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:07 WARN BlockManager: Persisting block rdd_46_82 to disk instead.
# 23/05/28 16:14:07 WARN MemoryStore: Not enough space to cache rdd_46_84 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:07 WARN BlockManager: Persisting block rdd_46_84 to disk instead.
# 23/05/28 16:14:07 WARN MemoryStore: Not enough space to cache rdd_46_86 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:07 WARN MemoryStore: Not enough space to cache rdd_46_83 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:07 WARN BlockManager: Persisting block rdd_46_83 to disk instead.
# 23/05/28 16:14:07 WARN MemoryStore: Not enough space to cache rdd_46_80 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:07 WARN BlockManager: Persisting block rdd_46_80 to disk instead.
# 23/05/28 16:14:07 WARN BlockManager: Persisting block rdd_46_86 to disk instead.
# 23/05/28 16:14:17 WARN MemoryStore: Not enough space to cache rdd_46_95 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:14:17 WARN BlockManager: Persisting block rdd_46_95 to disk instead.
# 23/05/28 16:14:18 WARN MemoryStore: Not enough space to cache rdd_46_90 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:14:18 WARN BlockManager: Persisting block rdd_46_90 to disk instead.
# 23/05/28 16:14:22 WARN MemoryStore: Not enough space to cache rdd_46_89 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:22 WARN MemoryStore: Not enough space to cache rdd_46_93 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:22 WARN BlockManager: Persisting block rdd_46_93 to disk instead.
# 23/05/28 16:14:22 WARN BlockManager: Persisting block rdd_46_89 to disk instead.
# 23/05/28 16:14:22 WARN MemoryStore: Not enough space to cache rdd_46_92 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:22 WARN BlockManager: Persisting block rdd_46_92 to disk instead.
# 23/05/28 16:14:22 WARN MemoryStore: Not enough space to cache rdd_46_91 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:22 WARN BlockManager: Persisting block rdd_46_91 to disk instead.
# 23/05/28 16:14:22 WARN MemoryStore: Not enough space to cache rdd_46_88 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:22 WARN BlockManager: Persisting block rdd_46_88 to disk instead.
# 23/05/28 16:14:32 WARN MemoryStore: Not enough space to cache rdd_46_99 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:14:32 WARN MemoryStore: Not enough space to cache rdd_46_102 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:14:32 WARN BlockManager: Persisting block rdd_46_99 to disk instead.
# 23/05/28 16:14:32 WARN BlockManager: Persisting block rdd_46_102 to disk instead.
# 23/05/28 16:14:34 WARN MemoryStore: Not enough space to cache rdd_46_103 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:14:34 WARN BlockManager: Persisting block rdd_46_103 to disk instead.
# 23/05/28 16:14:36 WARN MemoryStore: Not enough space to cache rdd_46_101 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:36 WARN BlockManager: Persisting block rdd_46_101 to disk instead.
# 23/05/28 16:14:36 WARN MemoryStore: Not enough space to cache rdd_46_98 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:36 WARN BlockManager: Persisting block rdd_46_98 to disk instead.
# 23/05/28 16:14:36 WARN MemoryStore: Not enough space to cache rdd_46_96 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:36 WARN BlockManager: Persisting block rdd_46_96 to disk instead.
# 23/05/28 16:14:44 WARN MemoryStore: Not enough space to cache rdd_22_111 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:14:47 WARN MemoryStore: Not enough space to cache rdd_46_108 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:14:47 WARN BlockManager: Persisting block rdd_46_108 to disk instead.
# 23/05/28 16:14:47 WARN MemoryStore: Not enough space to cache rdd_46_105 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:14:47 WARN BlockManager: Persisting block rdd_46_105 to disk instead.
# 23/05/28 16:14:51 WARN MemoryStore: Not enough space to cache rdd_46_107 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:51 WARN MemoryStore: Not enough space to cache rdd_46_109 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:14:51 WARN BlockManager: Persisting block rdd_46_109 to disk instead.
# 23/05/28 16:14:51 WARN BlockManager: Persisting block rdd_46_107 to disk instead.
# 23/05/28 16:14:57 WARN MemoryStore: Not enough space to cache rdd_22_119 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:15:00 WARN MemoryStore: Not enough space to cache rdd_46_114 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:15:00 WARN BlockManager: Persisting block rdd_46_114 to disk instead.
# 23/05/28 16:15:00 WARN MemoryStore: Not enough space to cache rdd_46_115 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:15:00 WARN BlockManager: Persisting block rdd_46_115 to disk instead.
# 23/05/28 16:15:04 WARN MemoryStore: Not enough space to cache rdd_46_112 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:15:04 WARN BlockManager: Persisting block rdd_46_112 to disk instead.
# 23/05/28 16:15:04 WARN MemoryStore: Not enough space to cache rdd_46_113 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:15:04 WARN BlockManager: Persisting block rdd_46_113 to disk instead.
# 23/05/28 16:15:05 WARN MemoryStore: Not enough space to cache rdd_46_118 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:15:05 WARN BlockManager: Persisting block rdd_46_118 to disk instead.
# 23/05/28 16:15:05 WARN MemoryStore: Not enough space to cache rdd_46_116 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:15:05 WARN BlockManager: Persisting block rdd_46_116 to disk instead.
# 23/05/28 16:15:14 WARN MemoryStore: Not enough space to cache rdd_46_123 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:15:14 WARN MemoryStore: Not enough space to cache rdd_46_120 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:15:14 WARN BlockManager: Persisting block rdd_46_123 to disk instead.
# 23/05/28 16:15:14 WARN BlockManager: Persisting block rdd_46_120 to disk instead.
# 23/05/28 16:15:14 WARN MemoryStore: Not enough space to cache rdd_46_121 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:15:14 WARN BlockManager: Persisting block rdd_46_121 to disk instead.
# 23/05/28 16:15:19 WARN MemoryStore: Not enough space to cache rdd_46_124 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:15:19 WARN BlockManager: Persisting block rdd_46_124 to disk instead.
#   summary        content_size
# 0   count           119999999
# 1    mean  30004.846926732058
# 2  stddev   17320.48756862254
# 3     min                   1
# 4     max               60000

# %%
status_freq_df = (logs_df_with_time
                     .groupBy('status')
                     .count()
                     .sort('status')
                     .cache())
print('Total distinct HTTP Status Codes:', status_freq_df.count())
status_freq_pd_df = (status_freq_df
                         .toPandas()
                         .sort_values(by=['count'],
                                      ascending=False))
status_freq_pd_df
# Out:
# 23/05/28 16:18:30 WARN MemoryStore: Not enough space to cache rdd_46_4 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:30 WARN MemoryStore: Not enough space to cache rdd_46_7 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:32 WARN MemoryStore: Not enough space to cache rdd_46_15 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:32 WARN MemoryStore: Not enough space to cache rdd_46_11 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:32 WARN MemoryStore: Not enough space to cache rdd_46_14 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:32 WARN MemoryStore: Not enough space to cache rdd_46_13 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:32 WARN MemoryStore: Not enough space to cache rdd_46_10 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:32 WARN MemoryStore: Not enough space to cache rdd_46_8 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:32 WARN MemoryStore: Not enough space to cache rdd_46_12 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:32 WARN MemoryStore: Not enough space to cache rdd_46_9 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:33 WARN MemoryStore: Not enough space to cache rdd_46_18 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:33 WARN MemoryStore: Not enough space to cache rdd_46_20 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:33 WARN MemoryStore: Not enough space to cache rdd_46_16 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:33 WARN MemoryStore: Not enough space to cache rdd_46_23 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:18:33 WARN MemoryStore: Not enough space to cache rdd_46_19 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:33 WARN MemoryStore: Not enough space to cache rdd_46_21 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:33 WARN MemoryStore: Not enough space to cache rdd_46_22 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:33 WARN MemoryStore: Not enough space to cache rdd_46_17 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:34 WARN MemoryStore: Not enough space to cache rdd_46_31 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:34 WARN MemoryStore: Not enough space to cache rdd_46_29 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:34 WARN MemoryStore: Not enough space to cache rdd_46_28 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:34 WARN MemoryStore: Not enough space to cache rdd_46_30 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:34 WARN MemoryStore: Not enough space to cache rdd_46_27 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:34 WARN MemoryStore: Not enough space to cache rdd_46_26 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:34 WARN MemoryStore: Not enough space to cache rdd_46_24 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:34 WARN MemoryStore: Not enough space to cache rdd_46_25 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:35 WARN MemoryStore: Not enough space to cache rdd_46_38 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:35 WARN MemoryStore: Not enough space to cache rdd_46_39 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:35 WARN MemoryStore: Not enough space to cache rdd_46_34 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:35 WARN MemoryStore: Not enough space to cache rdd_46_35 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:35 WARN MemoryStore: Not enough space to cache rdd_46_37 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:35 WARN MemoryStore: Not enough space to cache rdd_46_33 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:35 WARN MemoryStore: Not enough space to cache rdd_46_44 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:35 WARN MemoryStore: Not enough space to cache rdd_46_47 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:35 WARN MemoryStore: Not enough space to cache rdd_46_41 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:35 WARN MemoryStore: Not enough space to cache rdd_46_42 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:36 WARN MemoryStore: Not enough space to cache rdd_46_40 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:36 WARN MemoryStore: Not enough space to cache rdd_46_45 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:36 WARN MemoryStore: Not enough space to cache rdd_46_43 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:36 WARN MemoryStore: Not enough space to cache rdd_46_46 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:36 WARN MemoryStore: Not enough space to cache rdd_46_53 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:36 WARN MemoryStore: Not enough space to cache rdd_46_52 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:36 WARN MemoryStore: Not enough space to cache rdd_46_54 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:36 WARN MemoryStore: Not enough space to cache rdd_46_49 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:36 WARN MemoryStore: Not enough space to cache rdd_46_48 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:36 WARN MemoryStore: Not enough space to cache rdd_46_51 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_58 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_59 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_62 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_61 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_57 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_56 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_63 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_60 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_65 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_68 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_71 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_70 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_66 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:37 WARN MemoryStore: Not enough space to cache rdd_46_64 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:38 WARN MemoryStore: Not enough space to cache rdd_46_76 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:38 WARN MemoryStore: Not enough space to cache rdd_46_75 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:38 WARN MemoryStore: Not enough space to cache rdd_46_73 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:38 WARN MemoryStore: Not enough space to cache rdd_46_79 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:38 WARN MemoryStore: Not enough space to cache rdd_46_72 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:38 WARN MemoryStore: Not enough space to cache rdd_46_74 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:38 WARN MemoryStore: Not enough space to cache rdd_46_78 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:38 WARN MemoryStore: Not enough space to cache rdd_46_77 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_80 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_82 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_83 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_85 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_87 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_81 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_88 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_90 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_94 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_92 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_95 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_89 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_91 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:39 WARN MemoryStore: Not enough space to cache rdd_46_93 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_102 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_101 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_98 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_97 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_96 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_99 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_111 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_108 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_107 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_106 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_104 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_109 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_110 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:40 WARN MemoryStore: Not enough space to cache rdd_46_105 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:41 WARN MemoryStore: Not enough space to cache rdd_46_112 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:41 WARN MemoryStore: Not enough space to cache rdd_46_113 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:41 WARN MemoryStore: Not enough space to cache rdd_46_115 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:41 WARN MemoryStore: Not enough space to cache rdd_46_118 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:41 WARN MemoryStore: Not enough space to cache rdd_46_119 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:18:42 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_46_124 in memory.
# 23/05/28 16:18:42 WARN MemoryStore: Not enough space to cache rdd_46_125 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:18:42 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_46_126 in memory.
# 23/05/28 16:18:42 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_46_127 in memory.
# 23/05/28 16:18:42 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_46_123 in memory.
# 23/05/28 16:18:42 WARN MemoryStore: Not enough space to cache rdd_46_127 in memory! (computed 384.0 B so far)
# 23/05/28 16:18:42 WARN MemoryStore: Not enough space to cache rdd_46_123 in memory! (computed 384.0 B so far)
# 23/05/28 16:18:42 WARN MemoryStore: Not enough space to cache rdd_46_126 in memory! (computed 384.0 B so far)
# 23/05/28 16:18:42 WARN MemoryStore: Not enough space to cache rdd_46_124 in memory! (computed 384.0 B so far)
# Total distinct HTTP Status Codes: 7
#    status     count
# 3     403  17151477
# 6     502  17146966
# 1     303  17142150
# 4     404  17141234
# 2     304  17140649
# 0     200  17139337
# 5     500  17138186

# %%
paths_df = (logs_df
            .groupBy('endpoint')
            .count()
            .sort('count', ascending=False).limit(20))

paths_pd_df = paths_df.toPandas()
paths_pd_df
# Out:
# 23/05/28 16:22:54 WARN MemoryStore: Not enough space to cache rdd_22_13 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:54 WARN MemoryStore: Not enough space to cache rdd_22_14 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:54 WARN MemoryStore: Not enough space to cache rdd_22_9 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:54 WARN MemoryStore: Not enough space to cache rdd_22_8 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:55 WARN MemoryStore: Not enough space to cache rdd_22_18 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:22:55 WARN MemoryStore: Not enough space to cache rdd_22_22 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:22:55 WARN MemoryStore: Not enough space to cache rdd_22_20 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:22:55 WARN MemoryStore: Not enough space to cache rdd_22_23 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:22:55 WARN MemoryStore: Not enough space to cache rdd_22_21 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:55 WARN MemoryStore: Not enough space to cache rdd_22_17 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:55 WARN MemoryStore: Not enough space to cache rdd_22_19 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:55 WARN MemoryStore: Not enough space to cache rdd_22_16 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:57 WARN MemoryStore: Not enough space to cache rdd_22_28 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:57 WARN MemoryStore: Not enough space to cache rdd_22_31 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:57 WARN MemoryStore: Not enough space to cache rdd_22_27 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:57 WARN MemoryStore: Not enough space to cache rdd_22_25 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:57 WARN MemoryStore: Not enough space to cache rdd_22_30 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:57 WARN MemoryStore: Not enough space to cache rdd_22_26 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:57 WARN MemoryStore: Not enough space to cache rdd_22_29 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:57 WARN MemoryStore: Not enough space to cache rdd_22_24 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:58 WARN MemoryStore: Not enough space to cache rdd_22_38 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:58 WARN MemoryStore: Not enough space to cache rdd_22_35 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:58 WARN MemoryStore: Not enough space to cache rdd_22_33 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:58 WARN MemoryStore: Not enough space to cache rdd_22_32 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:58 WARN MemoryStore: Not enough space to cache rdd_22_34 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:22:58 WARN MemoryStore: Not enough space to cache rdd_22_39 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:00 WARN MemoryStore: Not enough space to cache rdd_22_40 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:00 WARN MemoryStore: Not enough space to cache rdd_22_46 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:00 WARN MemoryStore: Not enough space to cache rdd_22_43 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:00 WARN MemoryStore: Not enough space to cache rdd_22_47 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:00 WARN MemoryStore: Not enough space to cache rdd_22_45 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:00 WARN MemoryStore: Not enough space to cache rdd_22_44 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:00 WARN MemoryStore: Not enough space to cache rdd_22_42 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:00 WARN MemoryStore: Not enough space to cache rdd_22_41 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:01 WARN MemoryStore: Not enough space to cache rdd_22_49 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:01 WARN MemoryStore: Not enough space to cache rdd_22_54 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:01 WARN MemoryStore: Not enough space to cache rdd_22_48 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:01 WARN MemoryStore: Not enough space to cache rdd_22_51 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:01 WARN MemoryStore: Not enough space to cache rdd_22_52 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:01 WARN MemoryStore: Not enough space to cache rdd_22_55 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:02 WARN MemoryStore: Not enough space to cache rdd_22_59 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:02 WARN MemoryStore: Not enough space to cache rdd_22_60 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:02 WARN MemoryStore: Not enough space to cache rdd_22_63 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:02 WARN MemoryStore: Not enough space to cache rdd_22_62 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:02 WARN MemoryStore: Not enough space to cache rdd_22_58 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:02 WARN MemoryStore: Not enough space to cache rdd_22_61 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:02 WARN MemoryStore: Not enough space to cache rdd_22_57 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:02 WARN MemoryStore: Not enough space to cache rdd_22_56 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:03 WARN MemoryStore: Not enough space to cache rdd_22_69 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:03 WARN MemoryStore: Not enough space to cache rdd_22_64 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:03 WARN MemoryStore: Not enough space to cache rdd_22_71 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:03 WARN MemoryStore: Not enough space to cache rdd_22_65 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:03 WARN MemoryStore: Not enough space to cache rdd_22_67 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:03 WARN MemoryStore: Not enough space to cache rdd_22_68 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:05 WARN MemoryStore: Not enough space to cache rdd_22_79 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:05 WARN MemoryStore: Not enough space to cache rdd_22_76 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:05 WARN MemoryStore: Not enough space to cache rdd_22_78 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:05 WARN MemoryStore: Not enough space to cache rdd_22_74 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:05 WARN MemoryStore: Not enough space to cache rdd_22_75 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:05 WARN MemoryStore: Not enough space to cache rdd_22_73 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:23:05 WARN MemoryStore: Not enough space to cache rdd_22_72 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:05 WARN MemoryStore: Not enough space to cache rdd_22_77 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:06 WARN MemoryStore: Not enough space to cache rdd_22_80 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:06 WARN MemoryStore: Not enough space to cache rdd_22_84 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:06 WARN MemoryStore: Not enough space to cache rdd_22_83 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:06 WARN MemoryStore: Not enough space to cache rdd_22_81 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:06 WARN MemoryStore: Not enough space to cache rdd_22_87 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:06 WARN MemoryStore: Not enough space to cache rdd_22_85 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:08 WARN MemoryStore: Not enough space to cache rdd_22_94 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:08 WARN MemoryStore: Not enough space to cache rdd_22_91 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:08 WARN MemoryStore: Not enough space to cache rdd_22_90 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:08 WARN MemoryStore: Not enough space to cache rdd_22_89 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:08 WARN MemoryStore: Not enough space to cache rdd_22_93 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:08 WARN MemoryStore: Not enough space to cache rdd_22_95 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:08 WARN MemoryStore: Not enough space to cache rdd_22_88 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:08 WARN MemoryStore: Not enough space to cache rdd_22_92 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:09 WARN MemoryStore: Not enough space to cache rdd_22_102 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:09 WARN MemoryStore: Not enough space to cache rdd_22_103 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:09 WARN MemoryStore: Not enough space to cache rdd_22_100 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:09 WARN MemoryStore: Not enough space to cache rdd_22_98 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:09 WARN MemoryStore: Not enough space to cache rdd_22_96 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:09 WARN MemoryStore: Not enough space to cache rdd_22_97 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:10 WARN MemoryStore: Not enough space to cache rdd_22_111 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:10 WARN MemoryStore: Not enough space to cache rdd_22_107 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:10 WARN MemoryStore: Not enough space to cache rdd_22_105 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:10 WARN MemoryStore: Not enough space to cache rdd_22_104 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:10 WARN MemoryStore: Not enough space to cache rdd_22_106 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:10 WARN MemoryStore: Not enough space to cache rdd_22_110 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:23:10 WARN MemoryStore: Not enough space to cache rdd_22_108 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:10 WARN MemoryStore: Not enough space to cache rdd_22_109 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:12 WARN MemoryStore: Not enough space to cache rdd_22_119 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:12 WARN MemoryStore: Not enough space to cache rdd_22_114 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:12 WARN MemoryStore: Not enough space to cache rdd_22_117 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:12 WARN MemoryStore: Not enough space to cache rdd_22_118 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:12 WARN MemoryStore: Not enough space to cache rdd_22_116 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:12 WARN MemoryStore: Not enough space to cache rdd_22_113 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:13 WARN MemoryStore: Not enough space to cache rdd_22_125 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:13 WARN MemoryStore: Not enough space to cache rdd_22_120 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:13 WARN MemoryStore: Not enough space to cache rdd_22_121 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:13 WARN MemoryStore: Not enough space to cache rdd_22_122 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:13 WARN MemoryStore: Not enough space to cache rdd_22_124 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:13 WARN MemoryStore: Not enough space to cache rdd_22_126 in memory! (computed 17.7 MiB so far)
# 23/05/28 16:23:13 WARN MemoryStore: Not enough space to cache rdd_22_123 in memory! (computed 17.7 MiB so far)
#                                              endpoint   count
# 0   /Archives/edgar/data/0001724128/00012139002101...  802074
# 1   /Archives/edgar/data/0000205007/00011455492301...  801862
# 2   /Archives/edgar/data/1826671/00012139002302329...  801791
# 3   /Archives/edgar/data/0001866295/00011046592108...  801664
# 4   /Archives/edgar/data/0001330427/00009324711200...  801652
# 5   /Archives/edgar/data/0001704304/00009296381900...  801606
# 6   /Archives/edgar/data/0000101382/00011931251705...  801484
# 7   /Archives/edgar/data/0001203957/00011931251022...  801443
# 8   /Archives/edgar/data/0001326380/00013263802300...  801426
# 9   /Archives/edgar/data/1319616/00012091911901959...  801401
# 10  /Archives/edgar/data/879635/000117184322006367...  801328
# 11  /Archives/edgar/data/0001285785/00011814310805...  801261
# 12  /Archives/edgar/data/0001760283/00012139002101...  801226
# 13  /Archives/edgar/data/19411/0001104659-12-03771...  801170
# 14  /Archives/edgar/data/0001439124/00012928142200...  801104
# 15  /Archives/edgar/data/0001326380/00013263802300...  800991
# 16  /Archives/edgar/data/0001443125/00009324711200...  800982
# 17  /Archives/edgar/data/0001326380/00013263802300...  800961
# 18  /Archives/edgar/data/0001852440/00000000002200...  800936
# 19  /Archives/edgar/data/0001267332/00011749472100...  800907

# %%
week_map = {
    1: "Sunday",
    2: "Monday",
    3: "Tuesday",
    4: "Wednesday",
    5: "Thursday",
    6: "Friday",
    7: "Saturday"
}

def parse_day_of_week(dayOfWeek):
    return week_map[dayOfWeek]

# %%
udf_parse_day = udf(parse_day_of_week)
enpoint_day_of_week_df = logs_df_with_time.select(logs_df_with_time.endpoint, 
                             udf_parse_day(F.dayofweek('time')).alias("dayOfWeek"))
enpoint_day_of_week_df.show(5, truncate=False)
# Out:
# +---------------------------------------------------------------------------+---------+
# |endpoint                                                                   |dayOfWeek|
# +---------------------------------------------------------------------------+---------+
# |/Archives/edgar/data/0001179929/000117992922000054/a2022definitiveproxy.htm|Monday   |
# |/Archives/edgar/data/1935285/0001445546-23-001552-index.htm                |Monday   |
# |/Archives/edgar/data/0001179929/000117992923000043/moh-20230320_g26.jpg    |Monday   |
# |/Archives/edgar/data/0000019957/000110465921115352/tm2127556d2_424b3.htm   |Monday   |
# |/Archives/edgar/data/0001798682/000121390021017167/s131143_10k.htm         |Monday   |
# +---------------------------------------------------------------------------+---------+
# only showing top 5 rows

# %%
highest_invocations_df = (enpoint_day_of_week_df
                          .groupBy("endpoint", "dayOfWeek")
                          .count()
                          .sort("count", ascending=False)
                          .select(enpoint_day_of_week_df.dayOfWeek.alias("Day in a Week"), enpoint_day_of_week_df.endpoint, "count"))
highest_invocations_df.show(5, truncate=False)
# Out:
# 23/05/28 16:24:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:33 WARN MemoryStore: Not enough space to cache rdd_46_14 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:33 WARN MemoryStore: Not enough space to cache rdd_46_12 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:33 WARN MemoryStore: Not enough space to cache rdd_46_8 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:33 WARN MemoryStore: Not enough space to cache rdd_46_15 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:36 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:36 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:36 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:44 WARN MemoryStore: Not enough space to cache rdd_46_30 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:44 WARN MemoryStore: Not enough space to cache rdd_46_24 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:44 WARN MemoryStore: Not enough space to cache rdd_46_25 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:44 WARN MemoryStore: Not enough space to cache rdd_46_31 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:46 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:50 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:50 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:52 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:52 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:52 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:52 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:52 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:52 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:54 WARN MemoryStore: Not enough space to cache rdd_46_44 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:54 WARN MemoryStore: Not enough space to cache rdd_46_47 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:54 WARN MemoryStore: Not enough space to cache rdd_46_45 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:54 WARN MemoryStore: Not enough space to cache rdd_46_40 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:24:56 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:56 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:56 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:57 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:57 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:24:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:04 WARN MemoryStore: Not enough space to cache rdd_46_56 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:25:04 WARN MemoryStore: Not enough space to cache rdd_46_59 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:25:04 WARN MemoryStore: Not enough space to cache rdd_46_61 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:25:04 WARN MemoryStore: Not enough space to cache rdd_46_57 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:25:05 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:05 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:05 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:05 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:05 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:05 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:05 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:06 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:06 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:06 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:06 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:06 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:06 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:06 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:06 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:07 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:07 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:07 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:07 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:07 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:13 WARN MemoryStore: Not enough space to cache rdd_46_73 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:25:13 WARN MemoryStore: Not enough space to cache rdd_46_79 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:25:13 WARN MemoryStore: Not enough space to cache rdd_46_78 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:25:15 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:15 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:22 WARN MemoryStore: Not enough space to cache rdd_46_93 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:25:22 WARN MemoryStore: Not enough space to cache rdd_46_91 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:25:22 WARN MemoryStore: Not enough space to cache rdd_46_95 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:25:22 WARN MemoryStore: Not enough space to cache rdd_46_88 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:28 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:32 WARN MemoryStore: Not enough space to cache rdd_46_111 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:25:32 WARN MemoryStore: Not enough space to cache rdd_46_110 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:25:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:33 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:36 WARN MemoryStore: Not enough space to cache rdd_46_118 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:37 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:41 WARN MemoryStore: Not enough space to cache rdd_46_125 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:25:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:42 WARN MemoryStore: Not enough space to cache rdd_46_126 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:25:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:25:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# [Stage 30:====================================================> (125 + 3) / 128]
# +-------------+-----------------------------------------------------------------------------+------+
# |Day in a Week|endpoint                                                                     |count |
# +-------------+-----------------------------------------------------------------------------+------+
# |Monday       |/Archives/edgar/data/0001724128/000121390021017151/s131120_10k.htm           |802074|
# |Monday       |/Archives/edgar/data/0000205007/000114554923015369/0001145549-23-015369.txt  |801862|
# |Monday       |/Archives/edgar/data/1826671/000121390023023294/0001213900-23-023294.txt     |801791|
# |Monday       |/Archives/edgar/data/0001866295/000110465921080403/tm2117388d5_ex3-32g008.jpg|801664|
# |Monday       |/Archives/edgar/data/0001330427/000093247112005362/0000932471-12-005362.txt  |801652|
# +-------------+-----------------------------------------------------------------------------+------+
# only showing top 5 rows

# %%
highest_invocations_df.show(1, truncate=False)
# Out:
# 23/05/28 16:26:14 WARN MemoryStore: Not enough space to cache rdd_46_0 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:14 WARN MemoryStore: Not enough space to cache rdd_46_3 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:14 WARN MemoryStore: Not enough space to cache rdd_46_7 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:22 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:22 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:24 WARN MemoryStore: Not enough space to cache rdd_46_18 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:24 WARN MemoryStore: Not enough space to cache rdd_46_16 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:24 WARN MemoryStore: Not enough space to cache rdd_46_19 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:24 WARN MemoryStore: Not enough space to cache rdd_46_20 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:26 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:26 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:26 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:26 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:26 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:26 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:27 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:27 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:27 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:27 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:27 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:29 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:30 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:31 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:33 WARN MemoryStore: Not enough space to cache rdd_46_39 in memory! (computed 4.6 MiB so far)
# 23/05/28 16:26:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:34 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:35 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:37 WARN MemoryStore: Not enough space to cache rdd_46_45 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:37 WARN MemoryStore: Not enough space to cache rdd_46_46 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:37 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_46_47 in memory.
# 23/05/28 16:26:37 WARN MemoryStore: Not enough space to cache rdd_46_47 in memory! (computed 384.0 B so far)
# 23/05/28 16:26:38 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:39 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:40 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:41 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:44 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:44 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:44 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:44 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:44 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:44 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:44 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:44 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:44 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:47 WARN MemoryStore: Not enough space to cache rdd_46_56 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:47 WARN MemoryStore: Not enough space to cache rdd_46_63 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:47 WARN MemoryStore: Not enough space to cache rdd_46_59 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:47 WARN MemoryStore: Not enough space to cache rdd_46_58 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:48 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:50 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:50 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:52 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:56 WARN MemoryStore: Not enough space to cache rdd_46_74 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:56 WARN MemoryStore: Not enough space to cache rdd_46_77 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:56 WARN MemoryStore: Not enough space to cache rdd_46_79 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:56 WARN MemoryStore: Not enough space to cache rdd_46_78 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:26:57 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:59 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:26:59 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:03 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:03 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:03 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:03 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:03 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:03 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:04 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:05 WARN MemoryStore: Not enough space to cache rdd_46_91 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:27:05 WARN MemoryStore: Not enough space to cache rdd_46_88 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:27:05 WARN MemoryStore: Not enough space to cache rdd_46_92 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:27:05 WARN MemoryStore: Not enough space to cache rdd_46_94 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:27:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:11 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:12 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:12 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:12 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:12 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:12 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:12 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:12 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:14 WARN MemoryStore: Not enough space to cache rdd_46_109 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:27:15 WARN MemoryStore: Not enough space to cache rdd_46_110 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:27:15 WARN MemoryStore: Not enough space to cache rdd_46_111 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:27:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:18 WARN MemoryStore: Not enough space to cache rdd_46_112 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:27:19 WARN MemoryStore: Not enough space to cache rdd_46_119 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:21 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 23/05/28 16:27:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# [Stage 33:=====================================================>(126 + 2) / 128]
# +-------------+------------------------------------------------------------------+------+
# |Day in a Week|endpoint                                                          |count |
# +-------------+------------------------------------------------------------------+------+
# |Monday       |/Archives/edgar/data/0001724128/000121390021017151/s131120_10k.htm|802074|
# +-------------+------------------------------------------------------------------+------+
# only showing top 1 row

# %%
not_found_df = logs_df_with_time.filter(logs_df["status"] == 404).cache()
yearly_404_sorted_df = (not_found_df
                        .select(F.year("time").alias("Year"))
                        .groupBy("Year")
                        .count()
                        .sort("count", ascending=True).limit(10))
yearly_404_sorted_df.show(10, truncate=False)
# Out:
# 23/05/28 16:29:01 WARN MemoryStore: Not enough space to cache rdd_46_3 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:01 WARN MemoryStore: Not enough space to cache rdd_46_5 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:01 WARN MemoryStore: Not enough space to cache rdd_46_6 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:01 WARN MemoryStore: Not enough space to cache rdd_46_1 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:01 WARN MemoryStore: Not enough space to cache rdd_46_7 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:04 WARN MemoryStore: Not enough space to cache rdd_46_15 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:04 WARN MemoryStore: Not enough space to cache rdd_46_12 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:04 WARN MemoryStore: Not enough space to cache rdd_46_10 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:04 WARN MemoryStore: Not enough space to cache rdd_46_11 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:04 WARN MemoryStore: Not enough space to cache rdd_46_8 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:04 WARN MemoryStore: Not enough space to cache rdd_46_14 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:04 WARN MemoryStore: Not enough space to cache rdd_46_9 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:06 WARN MemoryStore: Not enough space to cache rdd_46_23 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:06 WARN MemoryStore: Not enough space to cache rdd_46_21 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:06 WARN MemoryStore: Not enough space to cache rdd_46_19 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:06 WARN MemoryStore: Not enough space to cache rdd_46_16 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:06 WARN MemoryStore: Not enough space to cache rdd_46_22 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:06 WARN MemoryStore: Not enough space to cache rdd_46_20 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:06 WARN MemoryStore: Not enough space to cache rdd_46_17 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:08 WARN MemoryStore: Not enough space to cache rdd_46_30 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:08 WARN MemoryStore: Not enough space to cache rdd_46_24 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:08 WARN MemoryStore: Not enough space to cache rdd_46_26 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:08 WARN MemoryStore: Not enough space to cache rdd_46_27 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:08 WARN MemoryStore: Not enough space to cache rdd_46_31 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:08 WARN MemoryStore: Not enough space to cache rdd_46_28 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:08 WARN MemoryStore: Not enough space to cache rdd_46_25 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:10 WARN MemoryStore: Not enough space to cache rdd_46_38 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:10 WARN MemoryStore: Not enough space to cache rdd_46_39 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:10 WARN MemoryStore: Not enough space to cache rdd_46_33 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:10 WARN MemoryStore: Not enough space to cache rdd_46_36 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:10 WARN MemoryStore: Not enough space to cache rdd_46_35 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:10 WARN MemoryStore: Not enough space to cache rdd_46_34 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:10 WARN MemoryStore: Not enough space to cache rdd_46_37 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:12 WARN MemoryStore: Not enough space to cache rdd_46_47 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:12 WARN MemoryStore: Not enough space to cache rdd_46_41 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:12 WARN MemoryStore: Not enough space to cache rdd_46_45 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:12 WARN MemoryStore: Not enough space to cache rdd_46_40 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:12 WARN MemoryStore: Not enough space to cache rdd_46_43 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:12 WARN MemoryStore: Not enough space to cache rdd_46_46 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:12 WARN MemoryStore: Not enough space to cache rdd_46_42 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:14 WARN MemoryStore: Not enough space to cache rdd_46_48 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:14 WARN MemoryStore: Not enough space to cache rdd_46_52 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:14 WARN MemoryStore: Not enough space to cache rdd_46_51 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:14 WARN MemoryStore: Not enough space to cache rdd_46_54 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:14 WARN MemoryStore: Not enough space to cache rdd_46_55 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:14 WARN MemoryStore: Not enough space to cache rdd_46_49 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:14 WARN MemoryStore: Not enough space to cache rdd_46_50 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:16 WARN MemoryStore: Not enough space to cache rdd_46_57 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:16 WARN MemoryStore: Not enough space to cache rdd_46_61 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:16 WARN MemoryStore: Not enough space to cache rdd_46_59 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:16 WARN MemoryStore: Not enough space to cache rdd_46_63 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:16 WARN MemoryStore: Not enough space to cache rdd_46_58 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:16 WARN MemoryStore: Not enough space to cache rdd_46_62 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:16 WARN MemoryStore: Not enough space to cache rdd_46_60 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:18 WARN MemoryStore: Not enough space to cache rdd_46_64 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:18 WARN MemoryStore: Not enough space to cache rdd_46_69 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:18 WARN MemoryStore: Not enough space to cache rdd_46_65 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:18 WARN MemoryStore: Not enough space to cache rdd_46_66 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:18 WARN MemoryStore: Not enough space to cache rdd_46_68 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:18 WARN MemoryStore: Not enough space to cache rdd_46_70 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:18 WARN MemoryStore: Not enough space to cache rdd_46_67 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:20 WARN MemoryStore: Not enough space to cache rdd_46_79 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:20 WARN MemoryStore: Not enough space to cache rdd_46_77 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:20 WARN MemoryStore: Not enough space to cache rdd_46_73 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:20 WARN MemoryStore: Not enough space to cache rdd_46_75 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:20 WARN MemoryStore: Not enough space to cache rdd_46_72 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:20 WARN MemoryStore: Not enough space to cache rdd_46_76 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:20 WARN MemoryStore: Not enough space to cache rdd_46_78 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:20 WARN MemoryStore: Not enough space to cache rdd_46_74 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:22 WARN MemoryStore: Not enough space to cache rdd_46_87 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:22 WARN MemoryStore: Not enough space to cache rdd_46_81 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:22 WARN MemoryStore: Not enough space to cache rdd_46_80 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:22 WARN MemoryStore: Not enough space to cache rdd_46_85 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:22 WARN MemoryStore: Not enough space to cache rdd_46_82 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:22 WARN MemoryStore: Not enough space to cache rdd_46_83 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:24 WARN MemoryStore: Not enough space to cache rdd_46_90 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:24 WARN MemoryStore: Not enough space to cache rdd_46_91 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:24 WARN MemoryStore: Not enough space to cache rdd_46_94 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:24 WARN MemoryStore: Not enough space to cache rdd_46_95 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:24 WARN MemoryStore: Not enough space to cache rdd_46_89 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:24 WARN MemoryStore: Not enough space to cache rdd_46_88 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:24 WARN MemoryStore: Not enough space to cache rdd_46_93 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:24 WARN MemoryStore: Not enough space to cache rdd_46_92 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:26 WARN MemoryStore: Not enough space to cache rdd_46_102 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:26 WARN MemoryStore: Not enough space to cache rdd_46_97 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:26 WARN MemoryStore: Not enough space to cache rdd_46_101 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:26 WARN MemoryStore: Not enough space to cache rdd_46_96 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:26 WARN MemoryStore: Not enough space to cache rdd_46_98 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:26 WARN MemoryStore: Not enough space to cache rdd_46_99 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:28 WARN MemoryStore: Not enough space to cache rdd_46_111 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:28 WARN MemoryStore: Not enough space to cache rdd_46_104 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:28 WARN MemoryStore: Not enough space to cache rdd_46_108 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:28 WARN MemoryStore: Not enough space to cache rdd_46_107 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:28 WARN MemoryStore: Not enough space to cache rdd_46_109 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:28 WARN MemoryStore: Not enough space to cache rdd_46_106 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:28 WARN MemoryStore: Not enough space to cache rdd_46_110 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:30 WARN MemoryStore: Not enough space to cache rdd_46_112 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:30 WARN MemoryStore: Not enough space to cache rdd_46_118 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:30 WARN MemoryStore: Not enough space to cache rdd_46_119 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:30 WARN MemoryStore: Not enough space to cache rdd_46_113 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:30 WARN MemoryStore: Not enough space to cache rdd_46_114 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:30 WARN MemoryStore: Not enough space to cache rdd_46_115 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:30 WARN MemoryStore: Not enough space to cache rdd_46_117 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:30 WARN MemoryStore: Not enough space to cache rdd_46_116 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:33 WARN MemoryStore: Not enough space to cache rdd_46_123 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:33 WARN MemoryStore: Not enough space to cache rdd_46_124 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:33 WARN MemoryStore: Not enough space to cache rdd_46_125 in memory! (computed 17.6 MiB so far)
# 23/05/28 16:29:33 WARN MemoryStore: Not enough space to cache rdd_46_120 in memory! (computed 9.0 MiB so far)
# 23/05/28 16:29:33 WARN MemoryStore: Not enough space to cache rdd_46_122 in memory! (computed 9.0 MiB so far)
# [Stage 36:===================================================>  (121 + 7) / 128]
# +----+--------+
# |Year|count   |
# +----+--------+
# |2118|17141234|
# +----+--------+
